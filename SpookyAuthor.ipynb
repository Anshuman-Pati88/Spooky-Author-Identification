# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.corpus import stopwords
import string
import xgboost as xgb
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn import ensemble, metrics, model_selection, naive_bayes
color = sns.color_palette()

# %matplotlib inline

nltk.download('stopwords')
eng_stopwords = set(stopwords.words("english"))
pd.options.mode.chained_assignment = None
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
## Read the train and test dataset and check the top few lines ##
train_df = pd.read_csv("/content/train.csv")
test_df = pd.read_csv("/content/test.csv")
print("Number of rows in train dataset : ",train_df.shape[0])
print("Number of rows in test dataset : ",test_df.shape[0])
# Out:
# Number of rows in train dataset :  19579
# Number of rows in test dataset :  8392

# %%
train_df.head()
# Out:
#         id                                               text author
# 0  id26305  This process, however, afforded me no means of...    EAP
# 1  id17569  It never once occurred to me that the fumbling...    HPL
# 2  id11008  In his left hand was a gold snuff box, from wh...    EAP
# 3  id27763  How lovely is spring As we looked from Windsor...    MWS
# 4  id12958  Finding nothing else, not even gold, the Super...    HPL

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cnt_srs = train_df['author'].value_counts()

plt.figure(figsize=(8, 4))
sns.barplot(x=cnt_srs.index, y=cnt_srs.values, alpha=0.8)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Author Name', fontsize=12)
plt.xticks(rotation=45)  # Rotate x labels for better readability
plt.show()

# %%
grouped_df = train_df.groupby('author')
for name, group in grouped_df:
    print("Author name : ", name)
    cnt = 0
    for ind, row in group.iterrows():
        print(row["text"])
        cnt += 1
        if cnt == 5:
            break
    print("\n")
# Out:
# Author name :  EAP
# This process, however, afforded me no means of ascertaining the dimensions of my dungeon; as I might make its circuit, and return to the point whence I set out, without being aware of the fact; so perfectly uniform seemed the wall.
# In his left hand was a gold snuff box, from which, as he capered down the hill, cutting all manner of fantastic steps, he took snuff incessantly with an air of the greatest possible self satisfaction.
# The astronomer, perhaps, at this point, took refuge in the suggestion of non luminosity; and here analogy was suddenly let fall.
# The surcingle hung in ribands from my body.
# I knew that you could not say to yourself 'stereotomy' without being brought to think of atomies, and thus of the theories of Epicurus; and since, when we discussed this subject not very long ago, I mentioned to you how singularly, yet with how little notice, the vague guesses of that noble Greek had met with confirmation in the late nebular cosmogony, I felt that you could not avoid casting your eyes upward to the great nebula in Orion, and I certainly expected that you would do so.
#
#
# Author name :  HPL
# It never once occurred to me that the fumbling might be a mere mistake.
# Finding nothing else, not even gold, the Superintendent abandoned his attempts; but a perplexed look occasionally steals over his countenance as he sits thinking at his desk.
# Herbert West needed fresh bodies because his life work was the reanimation of the dead.
# The farm like grounds extended back very deeply up the hill, almost to Wheaton Street.
# His facial aspect, too, was remarkable for its maturity; for though he shared his mother's and grandfather's chinlessness, his firm and precociously shaped nose united with the expression of his large, dark, almost Latin eyes to give him an air of quasi adulthood and well nigh preternatural intelligence.
#
#
# Author name :  MWS
# How lovely is spring As we looked from Windsor Terrace on the sixteen fertile counties spread beneath, speckled by happy cottages and wealthier towns, all looked as in former years, heart cheering and fair.
# A youth passed in solitude, my best years spent under your gentle and feminine fosterage, has so refined the groundwork of my character that I cannot overcome an intense distaste to the usual brutality exercised on board ship: I have never believed it to be necessary, and when I heard of a mariner equally noted for his kindliness of heart and the respect and obedience paid to him by his crew, I felt myself peculiarly fortunate in being able to secure his services.
# I confess that neither the structure of languages, nor the code of governments, nor the politics of various states possessed attractions for me.
# He shall find that I can feel my injuries; he shall learn to dread my revenge" A few days after he arrived.
# He had escaped me, and I must commence a destructive and almost endless journey across the mountainous ices of the ocean, amidst cold that few of the inhabitants could long endure and which I, the native of a genial and sunny climate, could not hope to survive.

# %%
## Number of words in the text ##
train_df["num_words"] = train_df["text"].apply(lambda x: len(str(x).split()))
test_df["num_words"] = test_df["text"].apply(lambda x: len(str(x).split()))

## Number of unique words in the text ##
train_df["num_unique_words"] = train_df["text"].apply(lambda x: len(set(str(x).split())))
test_df["num_unique_words"] = test_df["text"].apply(lambda x: len(set(str(x).split())))

## Number of characters in the text ##
train_df["num_chars"] = train_df["text"].apply(lambda x: len(str(x)))
test_df["num_chars"] = test_df["text"].apply(lambda x: len(str(x)))

## Number of stopwords in the text ##
train_df["num_stopwords"] = train_df["text"].apply(lambda x: len([w for w in str(x).lower().split() if w in eng_stopwords]))
test_df["num_stopwords"] = test_df["text"].apply(lambda x: len([w for w in str(x).lower().split() if w in eng_stopwords]))

## Number of punctuations in the text ##
train_df["num_punctuations"] =train_df['text'].apply(lambda x: len([c for c in str(x) if c in string.punctuation]) )
test_df["num_punctuations"] =test_df['text'].apply(lambda x: len([c for c in str(x) if c in string.punctuation]) )

## Number of title case words in the text ##
train_df["num_words_upper"] = train_df["text"].apply(lambda x: len([w for w in str(x).split() if w.isupper()]))
test_df["num_words_upper"] = test_df["text"].apply(lambda x: len([w for w in str(x).split() if w.isupper()]))

## Number of title case words in the text ##
train_df["num_words_title"] = train_df["text"].apply(lambda x: len([w for w in str(x).split() if w.istitle()]))
test_df["num_words_title"] = test_df["text"].apply(lambda x: len([w for w in str(x).split() if w.istitle()]))

## Average length of the words in the text ##
train_df["mean_word_len"] = train_df["text"].apply(lambda x: np.mean([len(w) for w in str(x).split()]))
test_df["mean_word_len"] = test_df["text"].apply(lambda x: np.mean([len(w) for w in str(x).split()]))

# %%
train_df['num_words'].loc[train_df['num_words']>80] = 80 #truncation for better visuals
plt.figure(figsize=(12,8))
sns.violinplot(x='author', y='num_words', data=train_df)
plt.xlabel('Author Name', fontsize=12)
plt.ylabel('Number of words in text', fontsize=12)
plt.title("Number of words by author", fontsize=15)
plt.show()
# Out:
# <ipython-input-12-bf56f77c0a98>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   train_df['num_words'].loc[train_df['num_words']>80] = 80 #truncation for better visuals

# %%
train_df['num_punctuations'].loc[train_df['num_punctuations']>10] = 10 #truncation for better visuals
plt.figure(figsize=(12,8))
sns.violinplot(x='author', y='num_punctuations', data=train_df)
plt.xlabel('Author Name', fontsize=12)
plt.ylabel('Number of puntuations in text', fontsize=12)
plt.title("Number of punctuations by author", fontsize=15)
plt.show()
# Out:
# <ipython-input-13-1fa9d0c7c289>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   train_df['num_punctuations'].loc[train_df['num_punctuations']>10] = 10 #truncation for better visuals

# %%
## Prepare the data for modeling ###
author_mapping_dict = {'EAP':0, 'HPL':1, 'MWS':2}
train_y = train_df['author'].map(author_mapping_dict)
train_id = train_df['id'].values
test_id = test_df['id'].values

### recompute the trauncated variables again ###
train_df["num_words"] = train_df["text"].apply(lambda x: len(str(x).split()))
test_df["num_words"] = test_df["text"].apply(lambda x: len(str(x).split()))
train_df["mean_word_len"] = train_df["text"].apply(lambda x: np.mean([len(w) for w in str(x).split()]))
test_df["mean_word_len"] = test_df["text"].apply(lambda x: np.mean([len(w) for w in str(x).split()]))

cols_to_drop = ['id', 'text']
train_X = train_df.drop(cols_to_drop+['author'], axis=1)
test_X = test_df.drop(cols_to_drop, axis=1)

# %%
def runXGB(train_X, train_y, test_X, test_y=None, test_X2=None, seed_val=0, child=1, colsample=0.3):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.1
    param['max_depth'] = 3
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = child
    param['subsample'] = 0.8
    param['colsample_bytree'] = colsample
    param['seed'] = seed_val
    num_rounds = 2000

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=50, verbose_eval=20)
    else:
        xgtest = xgb.DMatrix(test_X)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest, ntree_limit = model.best_ntree_limit)
    if test_X2 is not None:
        xgtest2 = xgb.DMatrix(test_X2)
        pred_test_y2 = model.predict(xgtest2, ntree_limit = model.best_ntree_limit)
    return pred_test_y, pred_test_y2, model

# %%
from sklearn import model_selection
from sklearn.metrics import log_loss
import numpy as np
import xgboost as xgb

def runXGB(train_X, train_y, val_X, val_y, test_X, seed_val=0, num_rounds=500, early_stopping_rounds=50):
    # Prepare the data
    xgtrain = xgb.DMatrix(train_X, label=train_y)
    xgval = xgb.DMatrix(val_X, label=val_y)
    xgtest = xgb.DMatrix(test_X)

    # Parameters
    params = {
        'objective': 'multi:softprob',
        'num_class': 3,  # Adjust based on your specific use case
        'eval_metric': 'mlogloss',
        'seed': seed_val,
    }

    # Train the model with validation set
    evals = [(xgtrain, 'train'), (xgval, 'val')]
    model = xgb.train(params, xgtrain, num_rounds, evals=evals, early_stopping_rounds=early_stopping_rounds, verbose_eval=True)

    # Predictions
    pred_val_y = model.predict(xgval)
    pred_test_y = model.predict(xgtest)

    return pred_val_y, pred_test_y, model

# K-Fold cross-validation
kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2017)
cv_scores = []
pred_full_test = 0
pred_train = np.zeros([train_df.shape[0], 3])
for dev_index, val_index in kf.split(train_X):
    dev_X, val_X = train_X.loc[dev_index], train_X.loc[val_index]
    dev_y, val_y = train_y[dev_index], train_y[val_index]
    pred_val_y, pred_test_y, model = runXGB(dev_X, dev_y, val_X, val_y, test_X, seed_val=0)
    pred_full_test += pred_test_y
    pred_train[val_index, :] = pred_val_y
    cv_scores.append(log_loss(val_y, pred_val_y))

print("cv scores:", cv_scores)

# %%
### Plot the important variables ###
fig, ax = plt.subplots(figsize=(12,12))
xgb.plot_importance(model, max_num_features=50, height=0.8, ax=ax)
plt.show()

# %%
### Fit transform the tfidf vectorizer ###
tfidf_vec = TfidfVectorizer(stop_words='english', ngram_range=(1,3))
full_tfidf = tfidf_vec.fit_transform(train_df['text'].values.tolist() + test_df['text'].values.tolist())
train_tfidf = tfidf_vec.transform(train_df['text'].values.tolist())
test_tfidf = tfidf_vec.transform(test_df['text'].values.tolist())

# %%
### Fit transform the tfidf vectorizer ###
tfidf_vec = TfidfVectorizer(stop_words='english', ngram_range=(1,3))
full_tfidf = tfidf_vec.fit_transform(train_df['text'].values.tolist() + test_df['text'].values.tolist())
train_tfidf = tfidf_vec.transform(train_df['text'].values.tolist())
test_tfidf = tfidf_vec.transform(test_df['text'].values.tolist())

# %%
def runMNB(train_X, train_y, test_X, test_y, test_X2):
    model = naive_bayes.MultinomialNB()
    model.fit(train_X, train_y)
    pred_test_y = model.predict_proba(test_X)
    pred_test_y2 = model.predict_proba(test_X2)
    return pred_test_y, pred_test_y2, model

# %%
cv_scores = []
pred_full_test = 0
pred_train = np.zeros([train_df.shape[0], 3])
kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2017)
for dev_index, val_index in kf.split(train_X):
    dev_X, val_X = train_tfidf[dev_index], train_tfidf[val_index]
    dev_y, val_y = train_y[dev_index], train_y[val_index]
    pred_val_y, pred_test_y, model = runMNB(dev_X, dev_y, val_X, val_y, test_tfidf)
    pred_full_test = pred_full_test + pred_test_y
    pred_train[val_index,:] = pred_val_y
    cv_scores.append(metrics.log_loss(val_y, pred_val_y))
print("Mean cv score : ", np.mean(cv_scores))
pred_full_test = pred_full_test / 5.
# Out:
# Mean cv score :  0.8422161983612853

# %%
import itertools
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        #print("Normalized confusion matrix")
    #else:
    #    print('Confusion matrix, without normalization')

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cnf_matrix = confusion_matrix(val_y, np.argmax(pred_val_y,axis=1))
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(8,8))
plot_confusion_matrix(cnf_matrix, classes=['EAP', 'HPL', 'MWS'],
                      title='Confusion matrix, without normalization')
plt.show()

# %%
n_comp = 20
svd_obj = TruncatedSVD(n_components=n_comp, algorithm='arpack')
svd_obj.fit(full_tfidf)
train_svd = pd.DataFrame(svd_obj.transform(train_tfidf))
test_svd = pd.DataFrame(svd_obj.transform(test_tfidf))

train_svd.columns = ['svd_word_'+str(i) for i in range(n_comp)]
test_svd.columns = ['svd_word_'+str(i) for i in range(n_comp)]
train_df = pd.concat([train_df, train_svd], axis=1)
test_df = pd.concat([test_df, test_svd], axis=1)
del full_tfidf, train_tfidf, test_tfidf, train_svd, test_svd

# %%
### Fit transform the count vectorizer ###
tfidf_vec = CountVectorizer(stop_words='english', ngram_range=(1,3))
tfidf_vec.fit(train_df['text'].values.tolist() + test_df['text'].values.tolist())
train_tfidf = tfidf_vec.transform(train_df['text'].values.tolist())
test_tfidf = tfidf_vec.transform(test_df['text'].values.tolist())

# %%
cv_scores = []
pred_full_test = 0
pred_train = np.zeros([train_df.shape[0], 3])
kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2017)
for dev_index, val_index in kf.split(train_X):
    dev_X, val_X = train_tfidf[dev_index], train_tfidf[val_index]
    dev_y, val_y = train_y[dev_index], train_y[val_index]
    pred_val_y, pred_test_y, model = runMNB(dev_X, dev_y, val_X, val_y, test_tfidf)
    pred_full_test = pred_full_test + pred_test_y
    pred_train[val_index,:] = pred_val_y
    cv_scores.append(metrics.log_loss(val_y, pred_val_y))
print("Mean cv score : ", np.mean(cv_scores))
pred_full_test = pred_full_test / 5.

# add the predictions as new features #
train_df["nb_cvec_eap"] = pred_train[:,0]
train_df["nb_cvec_hpl"] = pred_train[:,1]
train_df["nb_cvec_mws"] = pred_train[:,2]
test_df["nb_cvec_eap"] = pred_full_test[:,0]
test_df["nb_cvec_hpl"] = pred_full_test[:,1]
test_df["nb_cvec_mws"] = pred_full_test[:,2]
# Out:
# Mean cv score :  0.45091841616567424

# %%
cnf_matrix = confusion_matrix(val_y, np.argmax(pred_val_y,axis=1))
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(8,8))
plot_confusion_matrix(cnf_matrix, classes=['EAP', 'HPL', 'MWS'],
                      title='Confusion matrix of NB on word count, without normalization')
plt.show()

# %%
### Fit transform the tfidf vectorizer ###
tfidf_vec = TfidfVectorizer(ngram_range=(1,5), analyzer='char')
full_tfidf = tfidf_vec.fit_transform(train_df['text'].values.tolist() + test_df['text'].values.tolist())
train_tfidf = tfidf_vec.transform(train_df['text'].values.tolist())
test_tfidf = tfidf_vec.transform(test_df['text'].values.tolist())

cv_scores = []
pred_full_test = 0
pred_train = np.zeros([train_df.shape[0], 3])
kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2017)
for dev_index, val_index in kf.split(train_X):
    dev_X, val_X = train_tfidf[dev_index], train_tfidf[val_index]
    dev_y, val_y = train_y[dev_index], train_y[val_index]
    pred_val_y, pred_test_y, model = runMNB(dev_X, dev_y, val_X, val_y, test_tfidf)
    pred_full_test = pred_full_test + pred_test_y
    pred_train[val_index,:] = pred_val_y
    cv_scores.append(metrics.log_loss(val_y, pred_val_y))
print("Mean cv score : ", np.mean(cv_scores))
pred_full_test = pred_full_test / 5.

# add the predictions as new features #
train_df["nb_tfidf_char_eap"] = pred_train[:,0]
train_df["nb_tfidf_char_hpl"] = pred_train[:,1]
train_df["nb_tfidf_char_mws"] = pred_train[:,2]
test_df["nb_tfidf_char_eap"] = pred_full_test[:,0]
test_df["nb_tfidf_char_hpl"] = pred_full_test[:,1]
test_df["nb_tfidf_char_mws"] = pred_full_test[:,2]
# Out:
# Mean cv score :  0.790415258947422

# %%
n_comp = 20
svd_obj = TruncatedSVD(n_components=n_comp, algorithm='arpack')
svd_obj.fit(full_tfidf)
train_svd = pd.DataFrame(svd_obj.transform(train_tfidf))
test_svd = pd.DataFrame(svd_obj.transform(test_tfidf))

train_svd.columns = ['svd_char_'+str(i) for i in range(n_comp)]
test_svd.columns = ['svd_char_'+str(i) for i in range(n_comp)]
train_df = pd.concat([train_df, train_svd], axis=1)
test_df = pd.concat([test_df, test_svd], axis=1)
del full_tfidf, train_tfidf, test_tfidf, train_svd, test_svd

# %%
# Define the runXGB function without colsample parameter
def runXGB(train_X, train_y, val_X, val_y, test_X, seed_val=0, num_rounds=500, early_stopping_rounds=50):
    # Prepare the data
    xgtrain = xgb.DMatrix(train_X, label=train_y)
    xgval = xgb.DMatrix(val_X, label=val_y)
    xgtest = xgb.DMatrix(test_X)

    # Parameters
    params = {
        'objective': 'multi:softprob',
        'num_class': 3,  # Adjust based on your specific use case
        'eval_metric': 'mlogloss',
        'seed': seed_val,
        'colsample_bytree': 0.7  # Set colsample_bytree here if needed
    }

    # Train the model with validation set
    evals = [(xgtrain, 'train'), (xgval, 'val')]
    model = xgb.train(params, xgtrain, num_rounds, evals=evals, early_stopping_rounds=early_stopping_rounds, verbose_eval=True)

    # Predictions
    pred_val_y = model.predict(xgval)
    pred_test_y = model.predict(xgtest)

    return pred_val_y, pred_test_y, model

# Prepare data
cols_to_drop = ['id', 'text']
train_X = train_df.drop(cols_to_drop + ['author'], axis=1)
test_X = test_df.drop(cols_to_drop, axis=1)

# K-Fold cross-validation
kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2017)
cv_scores = []
pred_full_test = 0
pred_train = np.zeros([train_df.shape[0], 3])
for dev_index, val_index in kf.split(train_X):
    dev_X, val_X = train_X.loc[dev_index], train_X.loc[val_index]
    dev_y, val_y = train_y[dev_index], train_y[val_index]
    pred_val_y, pred_test_y, model = runXGB(dev_X, dev_y, val_X, val_y, test_X, seed_val=0)
    pred_full_test += pred_test_y
    pred_train[val_index, :] = pred_val_y
    cv_scores.append(log_loss(val_y, pred_val_y))

print("cv scores:", cv_scores)

# Prepare output DataFrame
out_df = pd.DataFrame(pred_full_test)
out_df.columns = ['EAP', 'HPL', 'MWS']
out_df.insert(0, 'id', test_id)
out_df.to_csv("sub_fe.csv", index=False)
# Out:
# [0]	train-mlogloss:0.81560	val-mlogloss:0.82532
# [1]	train-mlogloss:0.64576	val-mlogloss:0.66288
# [2]	train-mlogloss:0.53628	val-mlogloss:0.56312
# [3]	train-mlogloss:0.45971	val-mlogloss:0.49445
# [4]	train-mlogloss:0.40511	val-mlogloss:0.44644
# [5]	train-mlogloss:0.36653	val-mlogloss:0.41499
# [6]	train-mlogloss:0.33594	val-mlogloss:0.39157
# [7]	train-mlogloss:0.31272	val-mlogloss:0.37637
# [8]	train-mlogloss:0.29394	val-mlogloss:0.36459
# [9]	train-mlogloss:0.27817	val-mlogloss:0.35418
# [10]	train-mlogloss:0.26471	val-mlogloss:0.34668
# [11]	train-mlogloss:0.25411	val-mlogloss:0.34109
# [12]	train-mlogloss:0.24506	val-mlogloss:0.33581
# [13]	train-mlogloss:0.23779	val-mlogloss:0.33205
# [14]	train-mlogloss:0.23074	val-mlogloss:0.32972
# [15]	train-mlogloss:0.22406	val-mlogloss:0.32651
# [16]	train-mlogloss:0.21756	val-mlogloss:0.32372
# [17]	train-mlogloss:0.21206	val-mlogloss:0.32267
# [18]	train-mlogloss:0.20477	val-mlogloss:0.32054
# [19]	train-mlogloss:0.19886	val-mlogloss:0.31945
# [20]	train-mlogloss:0.19444	val-mlogloss:0.31849
# [21]	train-mlogloss:0.18838	val-mlogloss:0.31732
# [22]	train-mlogloss:0.18398	val-mlogloss:0.31750
# [23]	train-mlogloss:0.17732	val-mlogloss:0.31756
# [24]	train-mlogloss:0.17219	val-mlogloss:0.31713
# [25]	train-mlogloss:0.16859	val-mlogloss:0.31705
# [26]	train-mlogloss:0.16384	val-mlogloss:0.31734
# [27]	train-mlogloss:0.15901	val-mlogloss:0.31675
# [28]	train-mlogloss:0.15409	val-mlogloss:0.31675
# [29]	train-mlogloss:0.15034	val-mlogloss:0.31597
# [30]	train-mlogloss:0.14765	val-mlogloss:0.31685
# [31]	train-mlogloss:0.14478	val-mlogloss:0.31715
# [32]	train-mlogloss:0.14108	val-mlogloss:0.31767
# [33]	train-mlogloss:0.13726	val-mlogloss:0.31755
# [34]	train-mlogloss:0.13299	val-mlogloss:0.31716
# [35]	train-mlogloss:0.13078	val-mlogloss:0.31770
# [36]	train-mlogloss:0.12878	val-mlogloss:0.31788
# [37]	train-mlogloss:0.12594	val-mlogloss:0.31768
# [38]	train-mlogloss:0.12303	val-mlogloss:0.31766
# [39]	train-mlogloss:0.12035	val-mlogloss:0.31808
# [40]	train-mlogloss:0.11726	val-mlogloss:0.31821
# [41]	train-mlogloss:0.11464	val-mlogloss:0.31862
# [42]	train-mlogloss:0.11240	val-mlogloss:0.31908
# [43]	train-mlogloss:0.10973	val-mlogloss:0.31864
# [44]	train-mlogloss:0.10695	val-mlogloss:0.31869
# [45]	train-mlogloss:0.10469	val-mlogloss:0.31925
# [46]	train-mlogloss:0.10216	val-mlogloss:0.31959
# [47]	train-mlogloss:0.09985	val-mlogloss:0.31907
# [48]	train-mlogloss:0.09734	val-mlogloss:0.31943
# [49]	train-mlogloss:0.09426	val-mlogloss:0.31990
# [50]	train-mlogloss:0.09144	val-mlogloss:0.32024
# [51]	train-mlogloss:0.08922	val-mlogloss:0.32042
# [52]	train-mlogloss:0.08762	val-mlogloss:0.32049
# [53]	train-mlogloss:0.08563	val-mlogloss:0.32119
# [54]	train-mlogloss:0.08386	val-mlogloss:0.32181
# [55]	train-mlogloss:0.08237	val-mlogloss:0.32232
# [56]	train-mlogloss:0.08063	val-mlogloss:0.32190
# [57]	train-mlogloss:0.07849	val-mlogloss:0.32200
# [58]	train-mlogloss:0.07678	val-mlogloss:0.32228
# [59]	train-mlogloss:0.07545	val-mlogloss:0.32241
# [60]	train-mlogloss:0.07319	val-mlogloss:0.32307
# [61]	train-mlogloss:0.07181	val-mlogloss:0.32335
# [62]	train-mlogloss:0.07051	val-mlogloss:0.32407
# [63]	train-mlogloss:0.06927	val-mlogloss:0.32397
# [64]	train-mlogloss:0.06779	val-mlogloss:0.32427
# [65]	train-mlogloss:0.06621	val-mlogloss:0.32485
# [66]	train-mlogloss:0.06439	val-mlogloss:0.32454
# [67]	train-mlogloss:0.06294	val-mlogloss:0.32536
# [68]	train-mlogloss:0.06162	val-mlogloss:0.32560
# [69]	train-mlogloss:0.05983	val-mlogloss:0.32544
# [70]	train-mlogloss:0.05860	val-mlogloss:0.32546
# [71]	train-mlogloss:0.05735	val-mlogloss:0.32625
# [72]	train-mlogloss:0.05608	val-mlogloss:0.32668
# [73]	train-mlogloss:0.05492	val-mlogloss:0.32737
# [74]	train-mlogloss:0.05364	val-mlogloss:0.32897
# [75]	train-mlogloss:0.05254	val-mlogloss:0.32945
# [76]	train-mlogloss:0.05150	val-mlogloss:0.32989
# [77]	train-mlogloss:0.05034	val-mlogloss:0.33018
# [78]	train-mlogloss:0.04905	val-mlogloss:0.33110
# [0]	train-mlogloss:0.81547	val-mlogloss:0.82699
# [1]	train-mlogloss:0.64478	val-mlogloss:0.66679
# [2]	train-mlogloss:0.53478	val-mlogloss:0.56605
# [3]	train-mlogloss:0.45811	val-mlogloss:0.49885
# [4]	train-mlogloss:0.40329	val-mlogloss:0.45157
# [5]	train-mlogloss:0.36414	val-mlogloss:0.41978
# [6]	train-mlogloss:0.33295	val-mlogloss:0.39576
# [7]	train-mlogloss:0.30989	val-mlogloss:0.38015
# [8]	train-mlogloss:0.29118	val-mlogloss:0.36783
# [9]	train-mlogloss:0.27472	val-mlogloss:0.35781
# [10]	train-mlogloss:0.26016	val-mlogloss:0.34984
# [11]	train-mlogloss:0.24960	val-mlogloss:0.34371
# [12]	train-mlogloss:0.24039	val-mlogloss:0.33985
# [13]	train-mlogloss:0.23278	val-mlogloss:0.33713
# [14]	train-mlogloss:0.22601	val-mlogloss:0.33491
# [15]	train-mlogloss:0.21830	val-mlogloss:0.33275
# [16]	train-mlogloss:0.21191	val-mlogloss:0.33096
# [17]	train-mlogloss:0.20696	val-mlogloss:0.32976
# [18]	train-mlogloss:0.20078	val-mlogloss:0.32894
# [19]	train-mlogloss:0.19485	val-mlogloss:0.32797
# [20]	train-mlogloss:0.18989	val-mlogloss:0.32690
# [21]	train-mlogloss:0.18359	val-mlogloss:0.32732
# [22]	train-mlogloss:0.17887	val-mlogloss:0.32755
# [23]	train-mlogloss:0.17350	val-mlogloss:0.32738
# [24]	train-mlogloss:0.16901	val-mlogloss:0.32707
# [25]	train-mlogloss:0.16480	val-mlogloss:0.32665
# [26]	train-mlogloss:0.16123	val-mlogloss:0.32571
# [27]	train-mlogloss:0.15628	val-mlogloss:0.32585
# [28]	train-mlogloss:0.15195	val-mlogloss:0.32604
# [29]	train-mlogloss:0.14717	val-mlogloss:0.32604
# [30]	train-mlogloss:0.14317	val-mlogloss:0.32558
# [31]	train-mlogloss:0.13941	val-mlogloss:0.32567
# [32]	train-mlogloss:0.13663	val-mlogloss:0.32509
# [33]	train-mlogloss:0.13325	val-mlogloss:0.32556
# [34]	train-mlogloss:0.12948	val-mlogloss:0.32529
# [35]	train-mlogloss:0.12748	val-mlogloss:0.32567
# [36]	train-mlogloss:0.12420	val-mlogloss:0.32600
# [37]	train-mlogloss:0.12124	val-mlogloss:0.32619
# [38]	train-mlogloss:0.11836	val-mlogloss:0.32586
# [39]	train-mlogloss:0.11532	val-mlogloss:0.32639
# [40]	train-mlogloss:0.11335	val-mlogloss:0.32650
# [41]	train-mlogloss:0.11084	val-mlogloss:0.32696
# [42]	train-mlogloss:0.10830	val-mlogloss:0.32770
# [43]	train-mlogloss:0.10557	val-mlogloss:0.32746
# [44]	train-mlogloss:0.10325	val-mlogloss:0.32757
# [45]	train-mlogloss:0.10119	val-mlogloss:0.32821
# [46]	train-mlogloss:0.09837	val-mlogloss:0.32854
# [47]	train-mlogloss:0.09565	val-mlogloss:0.32976
# [48]	train-mlogloss:0.09374	val-mlogloss:0.33056
# [49]	train-mlogloss:0.09196	val-mlogloss:0.33046
# [50]	train-mlogloss:0.08983	val-mlogloss:0.33075
# [51]	train-mlogloss:0.08779	val-mlogloss:0.33140
# [52]	train-mlogloss:0.08545	val-mlogloss:0.33265
# [53]	train-mlogloss:0.08308	val-mlogloss:0.33344
# [54]	train-mlogloss:0.08097	val-mlogloss:0.33352
# [55]	train-mlogloss:0.07869	val-mlogloss:0.33444
# [56]	train-mlogloss:0.07717	val-mlogloss:0.33463
# [57]	train-mlogloss:0.07584	val-mlogloss:0.33544
# [58]	train-mlogloss:0.07443	val-mlogloss:0.33588
# [59]	train-mlogloss:0.07255	val-mlogloss:0.33529
# [60]	train-mlogloss:0.07054	val-mlogloss:0.33609
# [61]	train-mlogloss:0.06918	val-mlogloss:0.33640
# [62]	train-mlogloss:0.06809	val-mlogloss:0.33676
# [63]	train-mlogloss:0.06663	val-mlogloss:0.33692
# [64]	train-mlogloss:0.06471	val-mlogloss:0.33720
# [65]	train-mlogloss:0.06363	val-mlogloss:0.33782
# [66]	train-mlogloss:0.06221	val-mlogloss:0.33891
# [67]	train-mlogloss:0.06050	val-mlogloss:0.33923
# [68]	train-mlogloss:0.05935	val-mlogloss:0.34008
# [69]	train-mlogloss:0.05787	val-mlogloss:0.34071
# [70]	train-mlogloss:0.05685	val-mlogloss:0.34159
# [71]	train-mlogloss:0.05590	val-mlogloss:0.34221
# [72]	train-mlogloss:0.05492	val-mlogloss:0.34263
# [73]	train-mlogloss:0.05378	val-mlogloss:0.34278
# [74]	train-mlogloss:0.05232	val-mlogloss:0.34348
# [75]	train-mlogloss:0.05076	val-mlogloss:0.34345
# [76]	train-mlogloss:0.04974	val-mlogloss:0.34442
# [77]	train-mlogloss:0.04889	val-mlogloss:0.34477
# [78]	train-mlogloss:0.04751	val-mlogloss:0.34594
# [79]	train-mlogloss:0.04668	val-mlogloss:0.34622
# [80]	train-mlogloss:0.04552	val-mlogloss:0.34697
# [81]	train-mlogloss:0.04495	val-mlogloss:0.34698
# [0]	train-mlogloss:0.81441	val-mlogloss:0.82949
# [1]	train-mlogloss:0.64331	val-mlogloss:0.67021
# [2]	train-mlogloss:0.53336	val-mlogloss:0.57062
# [3]	train-mlogloss:0.45688	val-mlogloss:0.50329
# [4]	train-mlogloss:0.40245	val-mlogloss:0.45668
# [5]	train-mlogloss:0.36377	val-mlogloss:0.42696
# [6]	train-mlogloss:0.33313	val-mlogloss:0.40313
# [7]	train-mlogloss:0.31017	val-mlogloss:0.38639
# [8]	train-mlogloss:0.29119	val-mlogloss:0.37426
# [9]	train-mlogloss:0.27465	val-mlogloss:0.36473
# [10]	train-mlogloss:0.26165	val-mlogloss:0.35769
# [11]	train-mlogloss:0.25116	val-mlogloss:0.35212
# [12]	train-mlogloss:0.24238	val-mlogloss:0.34923
# [13]	train-mlogloss:0.23484	val-mlogloss:0.34610
# [14]	train-mlogloss:0.22726	val-mlogloss:0.34380
# [15]	train-mlogloss:0.22050	val-mlogloss:0.34116
# [16]	train-mlogloss:0.21393	val-mlogloss:0.33929
# [17]	train-mlogloss:0.20863	val-mlogloss:0.33746
# [18]	train-mlogloss:0.20334	val-mlogloss:0.33582
# [19]	train-mlogloss:0.19704	val-mlogloss:0.33496
# [20]	train-mlogloss:0.19225	val-mlogloss:0.33419
# [21]	train-mlogloss:0.18727	val-mlogloss:0.33358
# [22]	train-mlogloss:0.18188	val-mlogloss:0.33334
# [23]	train-mlogloss:0.17689	val-mlogloss:0.33310
# [24]	train-mlogloss:0.17180	val-mlogloss:0.33295
# [25]	train-mlogloss:0.16747	val-mlogloss:0.33332
# [26]	train-mlogloss:0.16259	val-mlogloss:0.33338
# [27]	train-mlogloss:0.15712	val-mlogloss:0.33279
# [28]	train-mlogloss:0.15314	val-mlogloss:0.33201
# [29]	train-mlogloss:0.15050	val-mlogloss:0.33170
# [30]	train-mlogloss:0.14668	val-mlogloss:0.33215
# [31]	train-mlogloss:0.14275	val-mlogloss:0.33156
# [32]	train-mlogloss:0.13972	val-mlogloss:0.33131
# [33]	train-mlogloss:0.13755	val-mlogloss:0.33132
# [34]	train-mlogloss:0.13322	val-mlogloss:0.33200
# [35]	train-mlogloss:0.13031	val-mlogloss:0.33203
# [36]	train-mlogloss:0.12788	val-mlogloss:0.33284
# [37]	train-mlogloss:0.12547	val-mlogloss:0.33256
# [38]	train-mlogloss:0.12292	val-mlogloss:0.33330
# [39]	train-mlogloss:0.12032	val-mlogloss:0.33352
# [40]	train-mlogloss:0.11752	val-mlogloss:0.33360
# [41]	train-mlogloss:0.11399	val-mlogloss:0.33488
# [42]	train-mlogloss:0.11230	val-mlogloss:0.33550
# [43]	train-mlogloss:0.10998	val-mlogloss:0.33584
# [44]	train-mlogloss:0.10829	val-mlogloss:0.33570
# [45]	train-mlogloss:0.10592	val-mlogloss:0.33633
# [46]	train-mlogloss:0.10256	val-mlogloss:0.33711
# [47]	train-mlogloss:0.10001	val-mlogloss:0.33760
# [48]	train-mlogloss:0.09743	val-mlogloss:0.33799
# [49]	train-mlogloss:0.09607	val-mlogloss:0.33808
# [50]	train-mlogloss:0.09383	val-mlogloss:0.33840
# [51]	train-mlogloss:0.09179	val-mlogloss:0.33821
# [52]	train-mlogloss:0.08983	val-mlogloss:0.33872
# [53]	train-mlogloss:0.08862	val-mlogloss:0.33936
# [54]	train-mlogloss:0.08633	val-mlogloss:0.33992
# [55]	train-mlogloss:0.08320	val-mlogloss:0.34093
# [56]	train-mlogloss:0.08138	val-mlogloss:0.34117
# [57]	train-mlogloss:0.07932	val-mlogloss:0.34207
# [58]	train-mlogloss:0.07735	val-mlogloss:0.34262
# [59]	train-mlogloss:0.07524	val-mlogloss:0.34293
# [60]	train-mlogloss:0.07348	val-mlogloss:0.34392
# [61]	train-mlogloss:0.07235	val-mlogloss:0.34414
# [62]	train-mlogloss:0.07076	val-mlogloss:0.34451
# [63]	train-mlogloss:0.06965	val-mlogloss:0.34493
# [64]	train-mlogloss:0.06852	val-mlogloss:0.34574
# [65]	train-mlogloss:0.06701	val-mlogloss:0.34551
# [66]	train-mlogloss:0.06525	val-mlogloss:0.34617
# [67]	train-mlogloss:0.06350	val-mlogloss:0.34709
# [68]	train-mlogloss:0.06184	val-mlogloss:0.34816
# [69]	train-mlogloss:0.06058	val-mlogloss:0.34872
# [70]	train-mlogloss:0.05935	val-mlogloss:0.34972
# [71]	train-mlogloss:0.05812	val-mlogloss:0.35074
# [72]	train-mlogloss:0.05701	val-mlogloss:0.35113
# [73]	train-mlogloss:0.05551	val-mlogloss:0.35201
# [74]	train-mlogloss:0.05417	val-mlogloss:0.35264
# [75]	train-mlogloss:0.05264	val-mlogloss:0.35340
# [76]	train-mlogloss:0.05138	val-mlogloss:0.35428
# [77]	train-mlogloss:0.04985	val-mlogloss:0.35513
# [78]	train-mlogloss:0.04902	val-mlogloss:0.35595
# [79]	train-mlogloss:0.04788	val-mlogloss:0.35652
# [80]	train-mlogloss:0.04669	val-mlogloss:0.35699
# [81]	train-mlogloss:0.04528	val-mlogloss:0.35815
# [0]	train-mlogloss:0.81532	val-mlogloss:0.82474
# [1]	train-mlogloss:0.64537	val-mlogloss:0.66126
# [2]	train-mlogloss:0.53685	val-mlogloss:0.55941
# [3]	train-mlogloss:0.46052	val-mlogloss:0.49094
# [4]	train-mlogloss:0.40629	val-mlogloss:0.44355
# [5]	train-mlogloss:0.36743	val-mlogloss:0.41322
# [6]	train-mlogloss:0.33686	val-mlogloss:0.38786
# [7]	train-mlogloss:0.31352	val-mlogloss:0.37104
# [8]	train-mlogloss:0.29419	val-mlogloss:0.35890
# [9]	train-mlogloss:0.27820	val-mlogloss:0.34858
# [10]	train-mlogloss:0.26425	val-mlogloss:0.34024
# [11]	train-mlogloss:0.25300	val-mlogloss:0.33438
# [12]	train-mlogloss:0.24475	val-mlogloss:0.33058
# [13]	train-mlogloss:0.23716	val-mlogloss:0.32664
# [14]	train-mlogloss:0.23027	val-mlogloss:0.32376
# [15]	train-mlogloss:0.22341	val-mlogloss:0.32152
# [16]	train-mlogloss:0.21734	val-mlogloss:0.31980
# [17]	train-mlogloss:0.21128	val-mlogloss:0.31832
# [18]	train-mlogloss:0.20580	val-mlogloss:0.31700
# [19]	train-mlogloss:0.19927	val-mlogloss:0.31558
# [20]	train-mlogloss:0.19400	val-mlogloss:0.31491
# [21]	train-mlogloss:0.18844	val-mlogloss:0.31428
# [22]	train-mlogloss:0.18378	val-mlogloss:0.31437
# [23]	train-mlogloss:0.17761	val-mlogloss:0.31352
# [24]	train-mlogloss:0.17451	val-mlogloss:0.31332
# [25]	train-mlogloss:0.17039	val-mlogloss:0.31222
# [26]	train-mlogloss:0.16549	val-mlogloss:0.31164
# [27]	train-mlogloss:0.16107	val-mlogloss:0.31124
# [28]	train-mlogloss:0.15691	val-mlogloss:0.31102
# [29]	train-mlogloss:0.15354	val-mlogloss:0.31084
# [30]	train-mlogloss:0.14957	val-mlogloss:0.31121
# [31]	train-mlogloss:0.14667	val-mlogloss:0.31058
# [32]	train-mlogloss:0.14315	val-mlogloss:0.31026
# [33]	train-mlogloss:0.13960	val-mlogloss:0.30995
# [34]	train-mlogloss:0.13639	val-mlogloss:0.31005
# [35]	train-mlogloss:0.13355	val-mlogloss:0.31025
# [36]	train-mlogloss:0.12908	val-mlogloss:0.31041
# [37]	train-mlogloss:0.12555	val-mlogloss:0.31124
# [38]	train-mlogloss:0.12258	val-mlogloss:0.31029
# [39]	train-mlogloss:0.11979	val-mlogloss:0.30994
# [40]	train-mlogloss:0.11745	val-mlogloss:0.31111
# [41]	train-mlogloss:0.11515	val-mlogloss:0.31104
# [42]	train-mlogloss:0.11217	val-mlogloss:0.31053
# [43]	train-mlogloss:0.10973	val-mlogloss:0.31086
# [44]	train-mlogloss:0.10707	val-mlogloss:0.31103
# [45]	train-mlogloss:0.10470	val-mlogloss:0.31142
# [46]	train-mlogloss:0.10234	val-mlogloss:0.31203
# [47]	train-mlogloss:0.10025	val-mlogloss:0.31266
# [48]	train-mlogloss:0.09896	val-mlogloss:0.31298
# [49]	train-mlogloss:0.09589	val-mlogloss:0.31349
# [50]	train-mlogloss:0.09438	val-mlogloss:0.31373
# [51]	train-mlogloss:0.09251	val-mlogloss:0.31544
# [52]	train-mlogloss:0.09052	val-mlogloss:0.31551
# [53]	train-mlogloss:0.08818	val-mlogloss:0.31600
# [54]	train-mlogloss:0.08658	val-mlogloss:0.31642
# [55]	train-mlogloss:0.08406	val-mlogloss:0.31751
# [56]	train-mlogloss:0.08207	val-mlogloss:0.31752
# [57]	train-mlogloss:0.08069	val-mlogloss:0.31759
# [58]	train-mlogloss:0.07870	val-mlogloss:0.31783
# [59]	train-mlogloss:0.07699	val-mlogloss:0.31852
# [60]	train-mlogloss:0.07496	val-mlogloss:0.31908
# [61]	train-mlogloss:0.07290	val-mlogloss:0.32026
# [62]	train-mlogloss:0.07112	val-mlogloss:0.32046
# [63]	train-mlogloss:0.06963	val-mlogloss:0.32061
# [64]	train-mlogloss:0.06857	val-mlogloss:0.32044
# [65]	train-mlogloss:0.06701	val-mlogloss:0.32056
# [66]	train-mlogloss:0.06506	val-mlogloss:0.32097
# [67]	train-mlogloss:0.06378	val-mlogloss:0.32119
# [68]	train-mlogloss:0.06294	val-mlogloss:0.32175
# [69]	train-mlogloss:0.06141	val-mlogloss:0.32219
# [70]	train-mlogloss:0.05976	val-mlogloss:0.32220
# [71]	train-mlogloss:0.05849	val-mlogloss:0.32246
# [72]	train-mlogloss:0.05708	val-mlogloss:0.32340
# [73]	train-mlogloss:0.05555	val-mlogloss:0.32387
# [74]	train-mlogloss:0.05393	val-mlogloss:0.32430
# [75]	train-mlogloss:0.05242	val-mlogloss:0.32448
# [76]	train-mlogloss:0.05070	val-mlogloss:0.32438
# [77]	train-mlogloss:0.04995	val-mlogloss:0.32496
# [78]	train-mlogloss:0.04851	val-mlogloss:0.32545
# [79]	train-mlogloss:0.04728	val-mlogloss:0.32563
# [80]	train-mlogloss:0.04649	val-mlogloss:0.32607
# [81]	train-mlogloss:0.04577	val-mlogloss:0.32669
# [82]	train-mlogloss:0.04471	val-mlogloss:0.32677
# [83]	train-mlogloss:0.04409	val-mlogloss:0.32715
# [84]	train-mlogloss:0.04331	val-mlogloss:0.32760
# [85]	train-mlogloss:0.04249	val-mlogloss:0.32803
# [86]	train-mlogloss:0.04172	val-mlogloss:0.32851
# [87]	train-mlogloss:0.04078	val-mlogloss:0.32920
# [88]	train-mlogloss:0.04016	val-mlogloss:0.32926
# [0]	train-mlogloss:0.81487	val-mlogloss:0.82591
# [1]	train-mlogloss:0.64492	val-mlogloss:0.66494
# [2]	train-mlogloss:0.53515	val-mlogloss:0.56394
# [3]	train-mlogloss:0.45936	val-mlogloss:0.49625
# [4]	train-mlogloss:0.40524	val-mlogloss:0.44962
# [5]	train-mlogloss:0.36683	val-mlogloss:0.41748
# [6]	train-mlogloss:0.33575	val-mlogloss:0.39434
# [7]	train-mlogloss:0.31357	val-mlogloss:0.37828
# [8]	train-mlogloss:0.29457	val-mlogloss:0.36610
# [9]	train-mlogloss:0.27846	val-mlogloss:0.35753
# [10]	train-mlogloss:0.26501	val-mlogloss:0.34952
# [11]	train-mlogloss:0.25422	val-mlogloss:0.34427
# [12]	train-mlogloss:0.24518	val-mlogloss:0.34055
# [13]	train-mlogloss:0.23795	val-mlogloss:0.33683
# [14]	train-mlogloss:0.23176	val-mlogloss:0.33456
# [15]	train-mlogloss:0.22491	val-mlogloss:0.33232
# [16]	train-mlogloss:0.21862	val-mlogloss:0.32969
# [17]	train-mlogloss:0.21292	val-mlogloss:0.32766
# [18]	train-mlogloss:0.20592	val-mlogloss:0.32618
# [19]	train-mlogloss:0.19945	val-mlogloss:0.32539
# [20]	train-mlogloss:0.19505	val-mlogloss:0.32407
# [21]	train-mlogloss:0.18946	val-mlogloss:0.32283
# [22]	train-mlogloss:0.18421	val-mlogloss:0.32208
# [23]	train-mlogloss:0.17881	val-mlogloss:0.32123
# [24]	train-mlogloss:0.17433	val-mlogloss:0.32065
# [25]	train-mlogloss:0.16948	val-mlogloss:0.32036
# [26]	train-mlogloss:0.16516	val-mlogloss:0.31953
# [27]	train-mlogloss:0.16186	val-mlogloss:0.31822
# [28]	train-mlogloss:0.15812	val-mlogloss:0.31809
# [29]	train-mlogloss:0.15476	val-mlogloss:0.31821
# [30]	train-mlogloss:0.15163	val-mlogloss:0.31877
# [31]	train-mlogloss:0.14825	val-mlogloss:0.31874
# [32]	train-mlogloss:0.14523	val-mlogloss:0.31883
# [33]	train-mlogloss:0.14227	val-mlogloss:0.31933
# [34]	train-mlogloss:0.13864	val-mlogloss:0.31933
# [35]	train-mlogloss:0.13426	val-mlogloss:0.31904
# [36]	train-mlogloss:0.13085	val-mlogloss:0.31890
# [37]	train-mlogloss:0.12865	val-mlogloss:0.31894
# [38]	train-mlogloss:0.12471	val-mlogloss:0.31935
# [39]	train-mlogloss:0.12230	val-mlogloss:0.31971
# [40]	train-mlogloss:0.11839	val-mlogloss:0.31979
# [41]	train-mlogloss:0.11566	val-mlogloss:0.31960
# [42]	train-mlogloss:0.11226	val-mlogloss:0.31949
# [43]	train-mlogloss:0.10990	val-mlogloss:0.31933
# [44]	train-mlogloss:0.10786	val-mlogloss:0.31908
# [45]	train-mlogloss:0.10579	val-mlogloss:0.31983
# [46]	train-mlogloss:0.10360	val-mlogloss:0.32040
# [47]	train-mlogloss:0.10103	val-mlogloss:0.32050
# [48]	train-mlogloss:0.09863	val-mlogloss:0.32101
# [49]	train-mlogloss:0.09667	val-mlogloss:0.32144
# [50]	train-mlogloss:0.09453	val-mlogloss:0.32206
# [51]	train-mlogloss:0.09296	val-mlogloss:0.32234
# [52]	train-mlogloss:0.09091	val-mlogloss:0.32243
# [53]	train-mlogloss:0.08862	val-mlogloss:0.32247
# [54]	train-mlogloss:0.08669	val-mlogloss:0.32259
# [55]	train-mlogloss:0.08498	val-mlogloss:0.32282
# [56]	train-mlogloss:0.08299	val-mlogloss:0.32320
# [57]	train-mlogloss:0.08120	val-mlogloss:0.32343
# [58]	train-mlogloss:0.07906	val-mlogloss:0.32369
# [59]	train-mlogloss:0.07745	val-mlogloss:0.32424
# [60]	train-mlogloss:0.07535	val-mlogloss:0.32469
# [61]	train-mlogloss:0.07395	val-mlogloss:0.32508
# [62]	train-mlogloss:0.07249	val-mlogloss:0.32559
# [63]	train-mlogloss:0.07111	val-mlogloss:0.32625
# [64]	train-mlogloss:0.06997	val-mlogloss:0.32686
# [65]	train-mlogloss:0.06812	val-mlogloss:0.32675
# [66]	train-mlogloss:0.06628	val-mlogloss:0.32635
# [67]	train-mlogloss:0.06474	val-mlogloss:0.32624
# [68]	train-mlogloss:0.06355	val-mlogloss:0.32680
# [69]	train-mlogloss:0.06250	val-mlogloss:0.32748
# [70]	train-mlogloss:0.06088	val-mlogloss:0.32736
# [71]	train-mlogloss:0.05935	val-mlogloss:0.32768
# [72]	train-mlogloss:0.05822	val-mlogloss:0.32841
# [73]	train-mlogloss:0.05699	val-mlogloss:0.32865
# [74]	train-mlogloss:0.05578	val-mlogloss:0.32940
# [75]	train-mlogloss:0.05448	val-mlogloss:0.32955
# [76]	train-mlogloss:0.05296	val-mlogloss:0.32963
# [77]	train-mlogloss:0.05180	val-mlogloss:0.33010
# [78]	train-mlogloss:0.05050	val-mlogloss:0.33075
# cv scores: [0.331511420124598, 0.3472634980622705, 0.3592247596114568, 0.32987170854709114, 0.3307508798609978]

# %%
### Plot the important variables ###
fig, ax = plt.subplots(figsize=(12,12))
xgb.plot_importance(model, max_num_features=50, height=0.8, ax=ax)
plt.show()

# %%
cnf_matrix = confusion_matrix(val_y, np.argmax(pred_val_y,axis=1))
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(8,8))
plot_confusion_matrix(cnf_matrix, classes=['EAP', 'HPL', 'MWS'],
                      title='Confusion matrix of XGB, without normalization')
plt.show()
